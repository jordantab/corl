# %%
import subprocess
import tempfile
import os
import pandas as pd
import time
import glob
import concurrent.futures
from typing import Tuple


DEFAULT_DATASET = "~/Downloads/data/improvement_pairs_additional_metadata.csv"
PUBLIC_TEST_CASES_FOLDER = "~/Downloads/codenet/public_test_cases/"
HIDDEN_TEST_CASES_FOLDER = "~/Downloads/codenet2/generated_test_cases/"
MAX_TIMEOUT = 5

# %%
def run_python_code_with_file_input(
    code: str, input_file_path: str
) -> Tuple[str, float, str]:
    # Create a temporary directory to hold the Python script
    with tempfile.TemporaryDirectory() as temp_dir:
        python_file_path = os.path.join(temp_dir, "code.py")

        # Write the Python code to a file
        with open(python_file_path, "w") as python_file:
            python_file.write(code)

        # Run the Python script with input redirected from the input file
        try:
            start_time = time.time()
            with open(input_file_path, "r") as input_file:
                run_process = subprocess.run(
                    ["python3", python_file_path],
                    stdin=input_file,
                    capture_output=True,
                    text=True,
                    timeout=MAX_TIMEOUT,
                )
            end_time = time.time()
            if run_process.returncode != 0:
                # Handle runtime errors
                return "Runtime Error", -1, ""
            return "Accepted", (end_time - start_time), run_process.stdout
        except subprocess.TimeoutExpired:
            return "Time Limit Exceeded", MAX_TIMEOUT, ""

def eval_output(output: str, expected_output_file: str) -> bool:
    with open(expected_output_file, "r") as expected_file:
        expected_output = expected_file.read()
        return output.strip() == expected_output.strip()

def run_single_test_case(code: str, input_file: str) -> Tuple[str, float, str]:
    expected_output_file = input_file.replace("input", "output")
    verdict, runtime, actual_output = run_python_code_with_file_input(code, input_file)
    if verdict != "Accepted":
        return verdict, runtime, input_file
    elif not eval_output(actual_output, expected_output_file):
        return "Wrong Answer", runtime, input_file
    return "Accepted", runtime, input_file

def run_tcs(code: str, problem_id: int) -> Tuple[str, float]:
    # Example paths for test cases, these need to be defined or configured
    sample_output_folder = f"{PUBLIC_TEST_CASES_FOLDER}p{problem_id:05d}"
    hidden_output_folder = f"{HIDDEN_TEST_CASES_FOLDER}p{problem_id:05d}"
    start_time = time.time()
    folders = [sample_output_folder, hidden_output_folder]
    test_cases = []
    execution_time = 0

    for folder in folders:
        input_files = glob.glob(os.path.join(os.path.expanduser(folder), "input.*.txt"))
        for input_file in input_files:
            test_cases.append((code, input_file))

    # print('all testcases', folders)
            
    with concurrent.futures.ThreadPoolExecutor() as executor:
        results = executor.map(lambda p: run_single_test_case(*p), test_cases)

    for verdict, runtime, input_file in results:
        if verdict != "Accepted":
            print(f"Failed on test case {input_file}")
            return verdict, 2 if verdict == "Time Limit Exceeded" else -1
        execution_time += runtime

    end_time = time.time()
    print(f"time to run all test cases: {end_time - start_time:.2f} seconds")
    return "Accepted", execution_time / len(test_cases)

# %%
def load_dataset(dataset=DEFAULT_DATASET):
    df = pd.read_csv(dataset, sep="\t")
    return df

df = load_dataset()

# %%
if __name__ == "__main__":
    sample_code = df.at[17, 'code_v0']
    python_df = df[df['language'] == 'Python']
    print(run_tcs(sample_code, 3352))
# Out:
# all testcases ['~/Downloads/codenet/public_test_cases/p03352', '~/Downloads/codenet2/generated_test_cases/p03352']
# Failed on test case /Users/zhuodannychen/Downloads/codenet/public_test_cases/p03352/input.3.txt
# ('Time Limit Exceeded', 2)

# %%
python_df.head(50)
# Out:
#         user_id problem_id language submission_id_v0 submission_id_v1  \
# 17   u000040786     p03352   Python       s655497536       s488933938
# 20   u013408661     p03352   Python       s605669799       s413110219
# 21   u015418072     p03352   Python       s258169947       s180991297
# 22   u015993380     p03352   Python       s133750393       s781843229
# 26   u020373088     p03352   Python       s068946442       s791061381
# 31   u038216098     p03352   Python       s711290106       s787230341
# 32   u046187684     p03352   Python       s285848029       s595372974
# 33   u046187684     p03352   Python       s595372974       s868533635
# 34   u046187684     p03352   Python       s868533635       s422164018
# 35   u049354454     p03352   Python       s498478248       s219265597
# 36   u049354454     p03352   Python       s715904138       s107820793
# 39   u057964173     p03352   Python       s194203721       s242489278
# 42   u068142202     p03352   Python       s367358878       s659839990
# 46   u077291787     p03352   Python       s578605260       s579099236
# 47   u077898957     p03352   Python       s653263344       s590891785
# 48   u079022693     p03352   Python       s670406944       s523152821
# 49   u080364835     p03352   Python       s274952706       s692234134
# 52   u089032001     p03352   Python       s114220291       s072725333
# 55   u094191970     p03352   Python       s111358133       s503234367
# 56   u094191970     p03352   Python       s951732353       s451496918
# 57   u094565093     p03352   Python       s154023656       s200860889
# 59   u097121858     p03352   Python       s143089990       s877241755
# 62   u106297876     p03352   Python       s788768545       s009483288
# 66   u124498235     p03352   Python       s088953832       s078914029
# 68   u134387396     p03352   Python       s363073760       s316247616
# 70   u139112865     p03352   Python       s601733086       s531703609
# 74   u155236040     p03352   Python       s806148922       s002137490
# 75   u156815136     p03352   Python       s673495848       s813219839
# 76   u156815136     p03352   Python       s687686079       s452640081
# 77   u156815136     p03352   Python       s452640081       s168315349
# 78   u156815136     p03352   Python       s946559986       s890886352
# 79   u156815136     p03352   Python       s890886352       s993834597
# 85   u186838327     p03352   Python       s065791815       s459152862
# 86   u187205913     p03352   Python       s308129316       s858152823
# 88   u189023301     p03352   Python       s783395979       s034407329
# 98   u208512038     p03352   Python       s174678909       s250753253
# 113  u241159583     p03352   Python       s154711430       s067297683
# 114  u241159583     p03352   Python       s140969048       s985069574
# 115  u241159583     p03352   Python       s985069574       s772212347
# 116  u242031676     p03352   Python       s277806970       s443809773
# 117  u243572357     p03352   Python       s589125055       s242115822
# 118  u244836567     p03352   Python       s905344935       s567470083
# 119  u249447366     p03352   Python       s602211697       s579616915
# 122  u257472411     p03352   Python       s649051573       s660885292
# 124  u263830634     p03352   Python       s905691142       s868847367
# 132  u281303342     p03352   Python       s914301769       s639733068
# 134  u285169240     p03352   Python       s449736167       s309556813
# 139  u291628833     p03352   Python       s124291801       s233025681
# 141  u293359059     p03352   Python       s564076066       s646332268
# 142  u297574184     p03352   Python       s789359830       s883469339
#
#      cpu_time_v0  cpu_time_v1  memory_v0  memory_v1            status_v0  \
# 17        2206.0         28.0     8992.0     9160.0  Time Limit Exceeded
# 20        2109.0         17.0   119576.0     3060.0  Time Limit Exceeded
# 21          18.0         17.0     2940.0     2940.0             Accepted
# 22        2106.0        164.0    40752.0    38256.0  Time Limit Exceeded
# 26          18.0         17.0     2940.0     2940.0             Accepted
# 31        2206.0         28.0     9044.0     9144.0  Time Limit Exceeded
# 32        2106.0        179.0    42516.0    38512.0  Time Limit Exceeded
# 33         179.0        173.0    38512.0    38256.0             Accepted
# 34         173.0         18.0    38256.0     3060.0             Accepted
# 35        2104.0         17.0     3064.0     3060.0  Time Limit Exceeded
# 36          18.0         17.0     3060.0     3060.0             Accepted
# 39         167.0         17.0    38384.0     3064.0             Accepted
# 42        2205.0        305.0     9036.0     9084.0  Time Limit Exceeded
# 46          22.0         18.0     3316.0     2940.0             Accepted
# 47          21.0         18.0     2940.0     2940.0             Accepted
# 48          18.0         17.0     2940.0     3060.0             Accepted
# 49          19.0         18.0     2940.0     2940.0             Accepted
# 52        2104.0         17.0     3064.0     3064.0  Time Limit Exceeded
# 55        2106.0         19.0    42044.0     2940.0  Time Limit Exceeded
# 56          22.0         18.0     2940.0     2940.0             Accepted
# 57        2104.0        148.0     2940.0    12424.0  Time Limit Exceeded
# 59          19.0         17.0     3064.0     3060.0             Accepted
# 62        2104.0         18.0     2940.0     2940.0  Time Limit Exceeded
# 66        2104.0         18.0     2940.0     2940.0  Time Limit Exceeded
# 68        2103.0         93.0     3060.0     3060.0  Time Limit Exceeded
# 70        2104.0         19.0     2940.0     2940.0  Time Limit Exceeded
# 74        2104.0         19.0     2940.0     2940.0  Time Limit Exceeded
# 75        2104.0         19.0     3064.0     2940.0  Time Limit Exceeded
# 76        2104.0         37.0     5148.0     5148.0  Time Limit Exceeded
# 77          37.0         19.0     5148.0     2940.0             Accepted
# 78         104.0         40.0    73012.0    10344.0             Accepted
# 79          40.0         34.0    10344.0    10300.0             Accepted
# 85         166.0         65.0    38256.0    61956.0             Accepted
# 86        2104.0         18.0     2940.0     3064.0  Time Limit Exceeded
# 88          29.0         23.0     9192.0     9048.0             Accepted
# 98        2205.0         31.0     9092.0     9192.0  Time Limit Exceeded
# 113         18.0         17.0     2940.0     2940.0             Accepted
# 114         29.0         28.0     8976.0     9004.0             Accepted
# 115         28.0         26.0     9004.0     9160.0             Accepted
# 116         78.0         17.0     2940.0     3060.0             Accepted
# 117       2104.0         17.0     2940.0     2940.0  Time Limit Exceeded
# 118       2206.0         28.0     8996.0     9136.0  Time Limit Exceeded
# 119         23.0         17.0     2940.0     3060.0             Accepted
# 122       2104.0         18.0     3060.0     3064.0  Time Limit Exceeded
# 124         18.0         17.0     2940.0     2940.0             Accepted
# 132         19.0         18.0     2940.0     3060.0             Accepted
# 134         19.0         17.0     2940.0     3060.0             Accepted
# 139       2106.0        186.0    42552.0    39280.0  Time Limit Exceeded
# 141         27.0         18.0     2940.0     3060.0             Accepted
# 142         20.0         17.0     3188.0     2940.0             Accepted
#
#     status_v1  improvement_frac  \
# 17   Accepted             98.73
# 20   Accepted             99.19
# 21   Accepted              5.56
# 22   Accepted             92.21
# 26   Accepted              5.56
# 31   Accepted             98.73
# 32   Accepted             91.50
# 33   Accepted              3.35
# 34   Accepted             89.60
# 35   Accepted             99.19
# 36   Accepted              5.56
# 39   Accepted             89.82
# 42   Accepted             86.17
# 46   Accepted             18.18
# 47   Accepted             14.29
# 48   Accepted              5.56
# 49   Accepted              5.26
# 52   Accepted             99.19
# 55   Accepted             99.10
# 56   Accepted             18.18
# 57   Accepted             92.97
# 59   Accepted             10.53
# 62   Accepted             99.14
# 66   Accepted             99.14
# 68   Accepted             95.58
# 70   Accepted             99.10
# 74   Accepted             99.10
# 75   Accepted             99.10
# 76   Accepted             98.24
# 77   Accepted             48.65
# 78   Accepted             61.54
# 79   Accepted             15.00
# 85   Accepted             60.84
# 86   Accepted             99.14
# 88   Accepted             20.69
# 98   Accepted             98.59
# 113  Accepted              5.56
# 114  Accepted              3.45
# 115  Accepted              7.14
# 116  Accepted             78.21
# 117  Accepted             99.19
# 118  Accepted             98.73
# 119  Accepted             26.09
# 122  Accepted             99.14
# 124  Accepted              5.56
# 132  Accepted              5.26
# 134  Accepted             10.53
# 139  Accepted             91.17
# 141  Accepted             33.33
# 142  Accepted             15.00
#
#                                                code_v0  \
# 17   x=int(input())\n\nc=1\n\nfor b in range(1,x):\...
# 20   num=[]\n\nfor i in range(32):\n\n  stack=i*i\n...
# 21   import sys\n\nimport math\n\n\n\ndef input():\...
# 22   x = int(input())\n\nvis = [False for _ in rang...
# 26   x = int(input())\n\ny = []\n\nfor i in range(1...
# 31   X=int(input())\n\nres=[]\n\nfor b in range(1,1...
# 32   from itertools import product\n\n\n\n\n\ndef s...
# 33   from math import floor, log, sqrt\n\n\n\n\n\nd...
# 34   from math import ceil, floor, log, sqrt\n\n\n\...
# 35   # coding: utf-8\n\n# Your code here!\n\n\n\nIN...
# 36   # coding: utf-8\n\n# Your code here!\n\n\n\nfr...
# 39   import sys\n\ndef input(): return sys.stdin.re...
# 42   x = int(input())\n\nans = []\n\nif x == 1:\n\n...
# 46   # ABC097B - Exponential\n\ndef main():\n\n    ...
# 47   x = int(input())\n\nbp = 0\n\nfor i in range(x...
# 48   X=int(input())\n\nn=1\n\nfor b in range(2,X):\...
# 49   x = int(input())\n\n\n\nans = 0\n\nfor i in ra...
# 52   X = int(input())\n\n \n\nans = 0\n\np = 2\n\nA...
# 55   x = int(input())\n\nans = 0\n\nfor b in range(...
# 56   x=int(input())\n\n\n\nfor i in range(x,-1,-1):...
# 57   X=int(input())\n\nmax=1\n\nfor j in range(2,X)...
# 59   def is_perfect_power(n):\n\n    if n == 1:\n\n...
# 62   x = int(input())\n\nans = 1\n\nl = [1]\n\nfor ...
# 66   x = int(input())\n\nc = [1]\n\nfor i in range(...
# 68   import math\n\nx = int(input())\n\n\n\nmaxs = ...
# 70   #097_B\n\nx=int(input())\n\nans=1\n\nfor b in ...
# 74   x = int(input())\n\nres_list = [1]\n\nfor b in...
# 75   #from statistics import median\n\n#import coll...
# 76   from statistics import median\n\n#import colle...
# 77   from statistics import median\n\n#import colle...
# 78   #from statistics import median\n\n#import coll...
# 79   #from statistics import median\n\n#import coll...
# 85   x = int(input())\n\nif x == 1:\n\n    print(1)...
# 86   x = int(input())\n\nans = 1\n\nfor i in range(...
# 88   n = int(input())\n\ns = set()\n\nfor i in rang...
# 98   x = int(input())\n\n\n\nif x == 1:\n\n    prin...
# 113  x = int(input())\n\nn = [1]\n\nfor i in range(...
# 114  x = int(input())\n\n\n\nans = [1]\n\nfor i in ...
# 115  x = int(input())\n\n\n\nans = [1]\n\nfor i in ...
# 116  x, mx = int(input()), 1\n\nfor i in range(2,x+...
# 117  n = int(input())\n\nm = 1\n\n\n\nfor i in rang...
# 118  a=int(input())\n\nd=0\n\nfor i in range(33):\n...
# 119  x = int(input())\n\n\n\nnum = 0\n\nif x == 1:\...
# 122  x = int(input())\n\n\n\nb = 1\n\np = 2\n\n\n\n...
# 124  X = int(input())\n\n\n\nans = 1\n\nfor i in ra...
# 132  X = int(input())\n\n\n\ns = [1]\n\nfor i in ra...
# 134  import math\n\nX = int(input())\n\nmax = 0\n\n...
# 139  x = int(input())\n\nans = 0\n\nfor a in range(...
# 141  X = int(input())\n\nans = 1\n\nt = min(X, 100)...
# 142  X = int(input())\n\n\n\npowers = {1}\n\nfor ba...
#
#                                                code_v1  code_v0_loc  \
# 17   x=int(input())\n\nc=1\n\nfor b in range(1,x):\...          7.0
# 20   num=[1]\n\nfor i in range(2,32):\n\n  stack=i*...         13.0
# 21   import sys\n\nimport math\n\n\n\ndef input():\...         12.0
# 22   x = int(input())\n\nvis = [False for _ in rang...         12.0
# 26   x = int(input())\n\ny = []\n\nfor i in range(1...         11.0
# 31   X=int(input())\n\nres=0\n\nfor b in range(1,10...          7.0
# 32   from math import floor, log, sqrt\n\n\n\n\n\nd...         11.0
# 33   from math import ceil, floor, log, sqrt\n\n\n\...         11.0
# 34   from math import ceil, floor, log, sqrt\n\n\n\...         15.0
# 35   # coding: utf-8\n\n# Your code here!\n\n\n\nfr...         28.0
# 36   from math import sqrt\n\nX=int(input())\n\nsqr...         14.0
# 39   import sys\n\ndef input(): return sys.stdin.re...         18.0
# 42   x = int(input())\n\nif x == 1:\n\n    print(1)...         13.0
# 46   # ABC097B - Exponential\n\ndef main():\n\n    ...         15.0
# 47   import math\n\n\n\nx=int(input())\n\na=int(mat...          7.0
# 48   def main():\n\n    X=int(input())\n\n    if X=...         13.0
# 49   x = int(input())\n\n\n\nans = 1\n\nfor i in ra...         11.0
# 52   X = int(input())\n\n \n\nans = 1\n\np = 2\n\nA...         24.0
# 55   x = int(input())\n\nans = 1\n\nfor b in range(...         11.0
# 56   x=int(input())\n\n\n\nans=1\n\nfor i in range(...         10.0
# 57   import numpy as np\n\nX=int(input())\n\nY=int(...          7.0
# 59   def is_perfect_power(n):\n\n    return n in {\...         29.0
# 62   x = int(input())\n\n\n\nans = 1\n\nfor b in ra...          9.0
# 66   x = int(input())\n\nc = [1]\n\nfor i in range(...          7.0
# 68   import math\n\nx = int(input())\n\n\n\nmaxs = ...         21.0
# 70   #097_B\n\nx=int(input())\n\nans=1\n\nfor b in ...          9.0
# 74   x = int(input())\n\nres_list = [1]\n\nfor b in...          7.0
# 75   #from statistics import median\n\n#import coll...         34.0
# 76   from statistics import median\n\n#import colle...         34.0
# 77   X = int(input())\n\nans = 1\n\nfor i in range(...         37.0
# 78   #from statistics import median\n\n#import coll...         38.0
# 79   #from statistics import median\n\n#import coll...         46.0
# 85   x = int(input())\n\nans = [1]\n\nfor i in rang...         14.0
# 86   x = int(input())\n\nans = 1\n\nfor i in range(...          9.0
# 88   n = int(input())\n\nt = [1, 4, 8, 9, 16, 25, 2...         27.0
# 98   x = int(input())\n\n\n\nif x == 1:\n\n    prin...         29.0
# 113  x = int(input())\n\n\n\nn = [1]\n\nfor i in ra...         11.0
# 114  x = int(input())\n\n\n\nans = [1]\n\nfor i in ...         11.0
# 115  x = int(input())\n\n\n\nans = [1]\n\nfor i in ...         11.0
# 116  beki = [0] * 1010\n\nbeki[1] = 1\n\nfor i in r...          5.0
# 117  n = int(input())\n\nm = 1\n\n\n\nfor i in rang...         10.0
# 118  a=int(input())\n\nd=0\n\ne=0\n\nfor i in range...         10.0
# 119  x = int(input())\n\n\n\nnum = 0\n\nif x == 1:\...         13.0
# 122  import sys\n\ninput = sys.stdin.buffer.readlin...         13.0
# 124  X = int(input())\n\n\n\nans = 1\n\nfor i in ra...         10.0
# 132  X = int(input())\n\nA = [False]*1001\n\nA[1] =...         10.0
# 134  import math\n\nX = int(input())\n\nmax = 0\n\n...         10.0
# 139  x = int(input())\n\nans = 0\n\nfor a in range(...          7.0
# 141  X = int(input())\n\nans = 1\n\nfor b in range(...          8.0
# 142  X = int(input())\n\n\n\npowers = {1}\n\nfor ba...         10.0
#
#      code_v1_loc
# 17           9.0
# 20          13.0
# 21          12.0
# 22          13.0
# 26           7.0
# 31           9.0
# 32          11.0
# 33          15.0
# 34          15.0
# 35          14.0
# 36          11.0
# 39          20.0
# 42          12.0
# 46          15.0
# 47          10.0
# 48          16.0
# 49          11.0
# 52          24.0
# 55           9.0
# 56           9.0
# 57           9.0
# 59          13.0
# 62           9.0
# 66           9.0
# 68          21.0
# 70          10.0
# 74           9.0
# 75          36.0
# 76          37.0
# 77           9.0
# 78          46.0
# 79          47.0
# 85          10.0
# 86          10.0
# 88          10.0
# 98          27.0
# 113         11.0
# 114         11.0
# 115         11.0
# 116         11.0
# 117         10.0
# 118         19.0
# 119         13.0
# 122         20.0
# 124         13.0
# 132         17.0
# 134         11.0
# 139         11.0
# 141          9.0
# 142         10.0
